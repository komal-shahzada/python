# %% [markdown]
# <a href="https://colab.research.google.com/github/komal-shahzada/python/blob/main/revision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Print statement screen par output dikhane ke liye istemal hoti hai
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
# Variable data store krny k liye istemal hota hai
name = "Komal"
age = 20
print(name, age)
# Out:
# Komal 20

# %%
# Python me basic data types
x = 10              # int
y = 3.5             # float
z = "Hello"         # str
is_student = True   # bool

# %%
# input() user se data lene ke liye hota hai (hamesha string return krta hai)
name = input("Enter your name: ")
print("Welcome", name)
# Out:
# Enter your name: komal
# Welcome komal

# %%
# Input ko integer me convert kiya hai
a = int(input("Enter a number: "))
b = int(input("Enter another number: "))
print("Sum =", a + b)
# Out:
# Enter a number: 1
# Enter another number: 2
# Sum = 3

# %%
# Arithmetic Operators: + , - , * , / , %
print(10 + 5)
print(10 % 3)
# Out:
# 15
# 1

# %%
age = int(input("Enter age: "))

if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible")
# Out:
# Enter age: 22
# Eligible to vote

# %%
marks = 75
if marks >= 60 and marks <= 100:
    print("Pass")
# Out:
# Pass

# %%
# 1 to 5 numbers print
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
x = 1
while x <= 5:
    print(x)
    x += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
text = "python programming"
print(text.upper())
print(text[0:6])   # slicing
# Out:
# PYTHON PROGRAMMING
# python

# %%
# List: Changeable collection
fruits = ["apple", "banana", "mango"]
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'orange']

# %%
for i in fruits:
    print(i)
# Out:
# apple
# banana
# mango
# orange

# %%
# Dictionary key-value pairs store krta hai
student = {"name": "Komal", "age": 20, "grade": "A"}
print(student["name"])
# Out:
# Komal

# %%
student["age"] = 21
print(student)
# Out:
# {'name': 'Komal', 'age': 21, 'grade': 'A'}

# %%
# Tuple list jaisa hota hai lekin ye change nahi hota (immutable)
colors = ("red", "green", "blue")
print(colors)
# Out:
# ('red', 'green', 'blue')

# %%
print(colors[0])   # red
# Out:
# red
