# %% [markdown]
# <a href="https://colab.research.google.com/github/komal-shahzada/python/blob/main/practice_codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

if num >= 10 and num <= 50:
    print("The number is between 10 and 50.")
else:
    print("The number is outside the range.")
# Out:
# Enter a number: 1
# The number is outside the range.

# %%
age = int(input("Enter your age: "))
citizen = input("Are you a citizen of Pakistan? (yes/no): ")

if age >= 18 and citizen.lower() == "yes":
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# Enter your age: 22
# Are you a citizen of Pakistan? (yes/no): yes
# You are eligible to vote.

# %%
password = input("Enter your password: ")

if len(password) >= 8 and any(ch.isdigit() for ch in password):
    print("Strong password ✅")
else:
    print("Weak password ❌")
# Out:
# Enter your password: 123
# Weak password ❌

# %%
maths = int(input("Enter Maths marks: "))
science = int(input("Enter Science marks: "))

if maths >= 40 and science >= 40:
    print("You passed in both subjects 🎉")
else:
    print("You failed ❌")
# Out:
# Enter Maths marks: 20
# Enter Science marks: 30
# You failed ❌

# %%
total = float(input("Enter total shopping amount: "))
member = input("Are you a member? (yes/no): ")

if total >= 5000 and member.lower() == "yes":
    print("You get a 20% discount 🎁")
else:
    print("No discount available")
# Out:
# Enter total shopping amount: 30
# Are you a member? (yes/no): no
# No discount available

# %%
total = float(input("Enter total shopping amount: "))
member = input("Are you a member? (yes/no): ")

if total >= 5000 and member.lower() == "yes":
    print("You get a 20% discount 🎁")
else:
    print("No discount available")
# Out:
# Enter total shopping amount: 60
# Are you a member? (yes/no): yes
# No discount available
