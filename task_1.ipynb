# %% [markdown]
# <a href="https://colab.research.google.com/github/komal-shahzada/python/blob/main/task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("Whta is your name?\n")
age= input("What is your age?\n")
hobby=input("What is your hobby?\n")
print(f"My name is {name} i am {age} years old My hobby is {hobby} .")
# Out:
# Whta is your name?
# komal
# What is your age?
# 22
# What is your hobby?
# exploring new things
# My name is komal i am 22 years old My hobby is exploring new things .
