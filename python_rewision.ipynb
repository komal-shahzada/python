# %% [markdown]
# <a href="https://colab.research.google.com/github/komal-shahzada/python/blob/main/python_rewision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mom = int(input("give money"))
if mom >= 10:
  print("chicken manchirium")
elif mom <=10 :
  print("fagita")
elif mom <=-1 :
  print("rice")
#else:
  #print("toffe")
# Out:
# give money-87
# fagita

# %%
a=2
b=3
if a>b:
  print(a)
else:
  print(b)
# Out:
# 3

# %%
a=str(input("enter your gender"))
if a=="male":
     print("good morning sir")
elif a=="female":
     print("good morning mam")
else:
     print("good mornning mam/sir")
# Out:
# enter your genderhjk
# good mornning mam/sir

# %%
a=int(input("enter the number"))
if a >=1:
  print(a," is an integer")
else:
  print(a,"is an odd number")
# Out:
# enter the number-2
# -2 is an odd number

# %%
age= int(input("enter yoyr age"))
if age>=18:
  print("you can vote")
else:
  print("you are not eliggible")
# Out:
# enter yoyr age49
# you can vote

# %%
a=int(input("enter year"))
if a % 400 ==0:
  print("it is a leap year")
elif a % 100 ==0:
  print("it is a century year")
# Out:
# enter year2009
